# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import zipfile as zf

# Study data files
hurricane_path = "C:/Users/spearjen/Desktop/unzipped/atlantic.csv"
# sst_at_path = "df2001_2004"

# Read the hurricane and sst + at data
hurricane_data = pd.read_csv(hurricane_path)
# sst_at_data = pd.read_csv(sst_at_path)

# %%
hurricane_data.head()
# Out:
#            ID                 Name      Date  Time Event Status Latitude  \
# 4    AL011851              UNNAMED  18510625  2100     L     HU    28.2N
# 48   AL041851              UNNAMED  18510823  2100     L     HU    30.1N
# 96   AL061851              UNNAMED  18511019  1500     L     TS    41.1N
# 127  AL011852              UNNAMED  18520826   600     L     HU    30.2N
# 163  AL031852              UNNAMED  18520912     0     L     HU    28.0N
#
#     Longitude  Maximum Wind  Minimum Pressure  ...  Low Wind SW  Low Wind NW  \
# 4       96.8W            80              -999  ...         -999         -999
# 48      85.7W           100              -999  ...         -999         -999
# 96      71.7W            50              -999  ...         -999         -999
# 127     88.6W           100               961  ...         -999         -999
# 163     82.8W            70              -999  ...         -999         -999
#
# ...

# %%
#filter to just landfall
hurricane_landfall = hurricane_data[(hurricane_data["Event"] == " L")]

    
index = hurricane_landfall.index
number_of_rows = len(index)
number_of_rows
# Out:
# 962

# %%
#format date
hurricane_landfall['Date'] = pd.to_datetime(str(hurricane_landfall["Date"]))
hurricane_landfall.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     431             try:
# --> 432                 values, tz = conversion.datetime_to_datetime64(arg)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-e39364b2454a> in <module>
#       1 #format date
# ...

# %%
#Groupby count year
hurricane_landfall_year = hurricane_landfall.groupby("Year")
