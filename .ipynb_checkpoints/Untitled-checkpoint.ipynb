# %%
import pandas
import pandas_gbq

# TODO: Set project_id to your Google Cloud Platform project ID.
project_id = "plucky-courier-292500"

sql = """
SELECT latitude, longitude, year, month, day, air_temperature, sea_surface_temp
FROM `bigquery-public-data.noaa_icoads.icoads_core_2015`
WHERE latitude >=15.623
AND latitude <=47.279
AND longitude >=-98.965
AND longitude <=-59.063
"""

df = pandas_gbq.read_gbq(sql, project_id=project_id)
# Out:
# ...
# Downloading: 100%|███████████████████████████████████████████████████| 22845833/22845833 [1:23:58<00:00, 4534.13rows/s]

# %%
df2015=df
df2015.head()
# Out:
#    latitude  longitude  year  month  day  air_temperature  sea_surface_temp
# 0     39.36     -74.42  2015      3   15              7.6               2.1
# 1     39.36     -74.42  2015     10   22             17.5              16.7
# 2     39.36     -74.42  2015      8   27             19.1              24.2
# 3     39.36     -74.42  2015      9    2             24.6              24.1
# 4     39.36     -74.42  2015     12   23             12.4              10.2

# %%
compression_opts = dict(method='zip',
                        archive_name='df2015.csv')  
df.to_csv('df2015.zip', index=False,
          compression=compression_opts)

# %%
from google.cloud import bigquery


GOOGLE_APPLICATION_CREDENTIALS = {"type": "service_account",project_id: "plucky-courier-292500",
        private_key_id: "c9dd7626e4f6bd62c6f3c13b875d4d77df823082",
            private_key: "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
                client_email: "hurricane@plucky-courier-292500.iam.gserviceaccount.com","client_id": "106322115309796195509",
                        auth_uri: "https://accounts.google.com/o/oauth2/auth",
                            token_uri: "https://oauth2.googleapis.com/token",
                                auth_provider_x509_cert_url: "https://www.googleapis.com/oauth2/v1/certs",
                                    client_x509_cert_url: "https://www.googleapis.com/robot/v1/metadata/x509/hurricane%40plucky-courier-292500.iam.gserviceaccount.com"}

# simple non parameterized query
client = bigquery.Client()

query = """
    SELECT latitude, longitude, year, month, day, avg(CONVERT(varchar, air_temperature)) as air_temp, avg(CONVERT(sea_surface_temp)) as sst 
    FROM `noaa_icoads.icoads_core_*` 
    GROUP BY year, latitude, longitude
    LIMIT 500
    
"""

query_res = client.query(query)  # Make an API request.

# to print in the console
for row in query_res:
    print(f'{row.year}, {row.month}, {row.day}: {row.air_temperature}, {row.sea_surface_temp}')
# Out:
#   File "<ipython-input-9-e2246cfc1d47>", line 4
#     GOOGLE_APPLICATION_CREDENTIALS = "type": "service_account","project_id": "plucky-courier-292500",
#                                            ^
# SyntaxError: invalid syntax
